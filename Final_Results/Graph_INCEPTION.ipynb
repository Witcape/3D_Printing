# %% [markdown]
# <a href="https://colab.research.google.com/github/Witcape/3D_Printing/blob/main/Final_Results/Graph_INCEPTION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for accuracy
models = ['Normal', 'SRGAN', 'CLAHE', 'SRCNN']
accuracy_final_inception = [89.66, 89.92, 92.51, 87.60]
accuracy_final_cropped_inception = [96.09, 95.35, 93.75, 90.62]

# X-axis positions
x = np.arange(len(models))

# Plotting the accuracy comparison in a single graph
plt.figure(figsize=(10, 6))
plt.bar(x - 0.2, accuracy_final_inception, 0.4, label='Final_INCEPTION', color='#1f77b4')  # Blue
plt.bar(x + 0.2, accuracy_final_cropped_inception, 0.4, label='Final_Cropped_INCEPTION', color='#ff7f0e')  # Orange

# Adding labels and title
plt.xlabel('Preprocessing Techniques')
plt.ylabel('Accuracy (%)')
plt.title('Accuracy Comparison: Final_INCEPTION vs. Final_Cropped_INCEPTION')
plt.xticks(x, models)
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Graph for Final_INCEPTION Dataset
plt.figure(figsize=(10, 6))
plt.bar(x, accuracy_final_inception, color='#1f77b4', width=0.5)
plt.xlabel('Preprocessing Techniques')
plt.ylabel('Accuracy (%)')
plt.title('Accuracy Comparison for Final_INCEPTION Dataset')
plt.xticks(x, models)
plt.tight_layout()
plt.show()

# Graph for Final_Cropped_INCEPTION Dataset
plt.figure(figsize=(10, 6))
plt.bar(x, accuracy_final_cropped_inception, color='#ff7f0e', width=0.5)
plt.xlabel('Preprocessing Techniques')
plt.ylabel('Accuracy (%)')
plt.title('Accuracy Comparison for Final_Cropped_INCEPTION Dataset')
plt.xticks(x, models)
plt.tight_layout()
plt.show()

# %% [markdown]
# # FINAL FDM

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define models and preprocessing techniques
models = ['ViT', 'DeiT', 'Swin', 'UNet', 'CNN', 'Inception']
preprocessing = ['Normal', 'SRGAN', 'CLAHE', 'SRCNN']

# Accuracy data for each model and preprocessing technique
accuracy_data = np.array([
    [87.34, 86.15, 86.30, 87.66],  # ViT
    [93.80, 90.93, 91.47, 92.44],  # DeiT
    [25.84, 37.03, 38.50, 34.51],  # Swin
    [38.76, 34.01, 39.79, 35.92],  # UNet
    [64.86, 55.42, 58.66, 66.25],  # CNN
    [89.66, 89.92, 92.51, 87.60]   # Inception
])

# Create an array for x-axis positions (one for each model)
x = np.arange(len(models))

# Bar width
width = 0.15

# Set a more elegant color palette
colors = ['#6C9E5D', '#F4A300', '#1F77B4', '#9467BD']  # Muted Green, Amber, Blue, Purple

# Plotting
fig, ax = plt.subplots(figsize=(12, 6))

# Plot bars for each preprocessing technique
for i, preprocessing_technique in enumerate(preprocessing):
    bars = ax.bar(x + (i - 1.5) * width, accuracy_data[:, i], width, label=preprocessing_technique, color=colors[i])

    # Display accuracy values on top of each bar with even smaller font size
    for bar in bars:
        yval = bar.get_height()
        ax.text(bar.get_x() + bar.get_width() / 2, yval + 0.1, f'{yval:.2f}%', ha='center', va='bottom', fontsize=6, rotation=90)

# Adding labels and title
ax.set_xlabel('Models')
ax.set_ylabel('Accuracy (%)')
ax.set_title('Accuracy of Models with Different Preprocessing Techniques')
ax.set_xticks(x)
ax.set_xticklabels(models)
# ax.legend(title="Preprocessing Techniques")

ax.set_ylim(0, 110)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define models and preprocessing techniques
models = ['ViT', 'DeiT', 'Swin', 'UNet', 'CNN', 'Inception']
preprocessing = ['Normal', 'SRGAN', 'CLAHE', 'SRCNN']

# Sensitivity data for each model and preprocessing technique
sensitivity_data = np.array([
    [87.34, 86.15, 86.30, 87.66],  # ViT
    [93.80, 90.93, 91.47, 92.44],  # DeiT
    [33.33, 33.33, 33.20, 33.33],  # Swin
    [38.76, 34.01, 39.79, 35.92],  # UNet
    [64.86, 55.42, 58.66, 66.25],  # CNN
    [89.66, 89.92, 92.51, 87.60]   # Inception
])

# Create an array for x-axis positions (one for each model)
x = np.arange(len(models))

# Bar width
width = 0.15

# Set a more elegant color palette
colors = ['#6C9E5D', '#F4A300', '#1F77B4', '#9467BD']  # Muted Green, Amber, Blue, Purple

# Plotting
fig, ax = plt.subplots(figsize=(12, 6))

# Plot bars for each preprocessing technique
for i, preprocessing_technique in enumerate(preprocessing):
    bars = ax.bar(x + (i - 1.5) * width, sensitivity_data[:, i], width, label=preprocessing_technique, color=colors[i])

    # Display Sensitivity values on top of each bar with smaller font size
    for bar in bars:
        yval = bar.get_height()
        ax.text(bar.get_x() + bar.get_width() / 2, yval + 0.1, f'{yval:.2f}%', ha='center', va='bottom', fontsize=6, rotation=90)

# Adding labels and title
ax.set_xlabel('Models')
ax.set_ylabel('Sensitivity (%)')
ax.set_title('Sensitivity of Models with Different Preprocessing Techniques')
ax.set_xticks(x)
ax.set_xticklabels(models)
# ax.legend(title="Preprocessing Techniques")

ax.set_ylim(0, 110)  # Set the upper limit to 100% to make space for the text

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define models and preprocessing techniques
models = ['ViT', 'DeiT', 'Swin', 'UNet', 'CNN', 'Inception']
preprocessing = ['Normal', 'SRGAN', 'CLAHE', 'SRCNN']

# Specificity data for each model and preprocessing technique
specificity_data = np.array([
    [93.67, 93.07, 93.15, 93.83],  # ViT
    [96.90, 95.47, 95.74, 96.22],  # DeiT
    [np.nan, np.nan, np.nan, np.nan],  # Swin (No Specificity Data)
    [34.45, 30.27, 39.51, 32.70],  # UNet
    [64.86, 55.42, 58.66, 66.25],  # CNN
    [94.83, 94.96, 96.25, 93.80]   # Inception
])

# Create an array for x-axis positions (one for each model)
x = np.arange(len(models))

# Bar width
width = 0.15

# Set a more elegant color palette
colors = ['#6C9E5D', '#F4A300', '#1F77B4', '#9467BD']  # Muted Green, Amber, Blue, Purple

# Plotting
fig, ax = plt.subplots(figsize=(12, 6))

# Plot bars for each preprocessing technique
for i, preprocessing_technique in enumerate(preprocessing):
    bars = ax.bar(x + (i - 1.5) * width, specificity_data[:, i], width, label=preprocessing_technique, color=colors[i])

    # Display Specificity values on top of each bar with smaller font size
    for bar in bars:
        yval = bar.get_height()
        if not np.isnan(yval):  # Avoid displaying NaN values
            ax.text(bar.get_x() + bar.get_width() / 2, yval + 0.1, f'{yval:.2f}%', ha='center', va='bottom', fontsize=6, rotation=90)

# Adding labels and title
ax.set_xlabel('Models')
ax.set_ylabel('Specificity (%)')
ax.set_title('Specificity of Models with Different Preprocessing Techniques')
ax.set_xticks(x)
ax.set_xticklabels(models)
# ax.legend(title="Preprocessing Techniques")

ax.set_ylim(0, 110)  # Set the upper limit to 100% to make space for the text

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define models and preprocessing techniques
models = ['ViT', 'DeiT', 'Swin', 'UNet', 'CNN', 'Inception']
preprocessing = ['Normal', 'SRGAN', 'CLAHE', 'SRCNN']

# F1 Score data for each model and preprocessing technique
f1_score_data = np.array([
    [87.36, 86.16, 86.31, 87.61],  # ViT
    [93.77, 90.92, 91.44, 92.42],  # DeiT
    [10.61, 20.01, 23.34, 17.71],  # Swin
    [28.32, 25.35, 41.02, 32.49],  # UNet
    [70.90, 71.56, 64.94, 69.73],  # CNN
    [90.09, 90.45, 92.78, 88.21]   # Inception
])

# Create an array for x-axis positions (one for each model)
x = np.arange(len(models))

# Bar width
width = 0.15

# Set a more elegant color palette
colors = ['#6C9E5D', '#F4A300', '#1F77B4', '#9467BD']  # Muted Green, Amber, Blue, Purple

# Plotting
fig, ax = plt.subplots(figsize=(12, 6))

# Plot bars for each preprocessing technique
for i, preprocessing_technique in enumerate(preprocessing):
    bars = ax.bar(x + (i - 1.5) * width, f1_score_data[:, i], width, label=preprocessing_technique, color=colors[i])

    # Display F1 score values on top of each bar with smaller font size
    for bar in bars:
        yval = bar.get_height()
        ax.text(bar.get_x() + bar.get_width() / 2, yval + 0.1, f'{yval:.2f}%', ha='center', va='bottom', fontsize=6, rotation=90)

# Adding labels and title
ax.set_xlabel('Models')
ax.set_ylabel('F1 Score (%)')
ax.set_title('F1 Score of Models with Different Preprocessing Techniques')
ax.set_xticks(x)
ax.set_xticklabels(models)

# Adding the legend back
# ax.legend(title="Preprocessing Techniques")

# Adjust the y-axis limit to give space for the labels
ax.set_ylim(0, 110)  # Set the upper limit to 100% to make space for the text

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define models and preprocessing techniques
models = ['ViT', 'DeiT', 'Swin', 'UNet', 'CNN', 'Inception']
preprocessing = ['Normal', 'SRGAN', 'CLAHE', 'SRCNN']

# Precision score data for each model and preprocessing technique
precision_data = np.array([
    [87.52, 86.54, 86.51, 87.88],  # ViT
    [93.81, 91.09, 91.50, 92.50],  # DeiT
    [6.68, 13.71, 25.92, 11.91],   # Swin
    [32.53, 29.03, 39.91, 32.52],  # UNet
    [63.69, 51.49, 52.91, 64.39],  # CNN
    [89.64, 89.93, 92.54, 87.51]   # Inception
])

# Create an array for x-axis positions (one for each model)
x = np.arange(len(models))

# Bar width
width = 0.15

# Set a more elegant color palette
colors = ['#6C9E5D', '#F4A300', '#1F77B4', '#9467BD']  # Muted Green, Amber, Blue, Purple

# Plotting
fig, ax = plt.subplots(figsize=(12, 6))

# Plot bars for each preprocessing technique
for i, preprocessing_technique in enumerate(preprocessing):
    bars = ax.bar(x + (i - 1.5) * width, precision_data[:, i], width, label=preprocessing_technique, color=colors[i])

    # Display Precision values on top of each bar with smaller font size
    for bar in bars:
        yval = bar.get_height()
        ax.text(bar.get_x() + bar.get_width() / 2, yval + 0.1, f'{yval:.2f}%', ha='center', va='bottom', fontsize=6, rotation=90)

# Adding labels and title
ax.set_xlabel('Models')
ax.set_ylabel('Precision (%)')
ax.set_title('Precision of Models with Different Preprocessing Techniques')
ax.set_xticks(x)
ax.set_xticklabels(models)

# Adding the legend back
# ax.legend(title="Preprocessing Techniques")

# Adjust the y-axis limit to give space for the labels
ax.set_ylim(0, 110)  # Set the upper limit to 100% to make space for the text

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define models and preprocessing techniques
models = ['ViT', 'DeiT', 'Swin', 'UNet', 'CNN', 'Inception']
preprocessing = ['Normal', 'SRGAN', 'CLAHE', 'SRCNN']

# Matthew Correlation Coefficient (Mathew CC) data for each model and preprocessing technique
mathew_cc_data = np.array([
    [0.8073, 0.7889, 0.7916, 0.8121],  # ViT
    [0.9062, 0.8629, 0.8708, 0.8853],  # DeiT
    [0.0, 0.0, -0.007, 0.0],          # Swin
    [0.0238, -0.0599, 0.0826, -0.0054], # UNet
    [0.4734, 0.3681, 0.436, 0.5235],   # CNN
    [0.846, 0.8473, 0.8877, 0.8126]    # Inception
])

# Create an array for x-axis positions (one for each model)
x = np.arange(len(models))

# Bar width
width = 0.15

# Set a more elegant color palette
colors = ['#6C9E5D', '#F4A300', '#1F77B4', '#9467BD']  # Muted Green, Amber, Blue, Purple

# Plotting
fig, ax = plt.subplots(figsize=(12, 6))

# Plot bars for each preprocessing technique
for i, preprocessing_technique in enumerate(preprocessing):
    bars = ax.bar(x + (i - 1.5) * width, mathew_cc_data[:, i], width, label=preprocessing_technique, color=colors[i])

    # Display Mathew CC values vertically above each bar
    for bar in bars:
        yval = bar.get_height()
        ax.text(bar.get_x() + bar.get_width() / 2, yval + 0.005, f'{yval*100:.2f}%', ha='center', va='bottom', fontsize=6, rotation = 90)

# Adding labels and title
ax.set_xlabel('Models')
ax.set_ylabel('Matthew’s Correlation Coefficient (Mathew CC)')
ax.set_title('Matthew’s Correlation Coefficient (Mathew CC) of Models with Different Preprocessing Techniques')
ax.set_xticks(x)
ax.set_xticklabels(models)
# ax.legend(title="Preprocessing Techniques")

# Adjust the y-axis limit to make space for the labels
ax.set_ylim(0, 1.1)  # Set the upper limit to 1.1 to give space for the text

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define models and preprocessing techniques
models = ['ViT', 'DeiT', 'Swin', 'UNet', 'CNN', 'Inception']
preprocessing = ['Normal', 'SRGAN', 'CLAHE', 'SRCNN']

# Kappa values for each model and preprocessing technique
kappa_data = np.array([
    [0.8067, 0.7875, 0.7908, 0.8104],  # ViT
    [0.9058, 0.8619, 0.8704, 0.8848],  # DeiT
    [0, 0, -0.0024, 0],  # Swin
    [0.0214, -0.0548, 0.0814, -0.005],  # UNet
    [0.4477, 0.2919, 0.3885, 0.4996],  # CNN
    [0.8437, 0.8454, 0.8867, 0.8097]   # Inception
])

# Create an array for x-axis positions (one for each model)
x = np.arange(len(models))

# Bar width
width = 0.15

# Set a more elegant color palette
colors = ['#6C9E5D', '#F4A300', '#1F77B4', '#9467BD']  # Muted Green, Amber, Blue, Purple

# Plotting
fig, ax = plt.subplots(figsize=(12, 6))

# Plot bars for each preprocessing technique
for i, preprocessing_technique in enumerate(preprocessing):
    bars = ax.bar(x + (i - 1.5) * width, kappa_data[:, i], width, label=preprocessing_technique, color=colors[i])

    # Display Kappa values on top of each bar with smaller font size
    for bar in bars:
        yval = bar.get_height()
        ax.text(bar.get_x() + bar.get_width() / 2, yval + 0.01, f'{yval:.4f}', ha='center', va='bottom', fontsize=6, rotation = 90)

# Adding labels and title
ax.set_xlabel('Models')
ax.set_ylabel('Kappa')
ax.set_title('Kappa of Models with Different Preprocessing Techniques')
ax.set_xticks(x)
ax.set_xticklabels(models)
# ax.legend(title="Preprocessing Techniques")

ax.set_ylim(0, 1.1)  # Set the upper limit to 1.1 to give space for the text

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Final Cropped FDM

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define models and preprocessing techniques
models = ['ViT', 'DeiT', 'Swin', 'UNet', 'CNN', 'Inception']
preprocessing = ['Normal', 'SRGAN', 'CLAHE', 'SRCNN']

# Accuracy values for each model and preprocessing technique
accuracy_data = np.array([
    [96.09, 95.35, 96.88, 94.16],  # ViT
    [96.88, 96.90, 97.66, 94.89],  # DeiT
    [32.81, 32.56, 32.81, 35.04],  # Swin
    [53.91, 50.39, 50.78, 56.25],  # UNet
    [78.91, 93.80, 70.31, 86.86],  # CNN
    [96.09, 95.35, 93.75, 90.62]   # Inception
])

# Create an array for x-axis positions (one for each model)
x = np.arange(len(models))

# Bar width
width = 0.15

# Set a more elegant color palette
colors = ['#6C9E5D', '#F4A300', '#1F77B4', '#9467BD']  # Muted Green, Amber, Blue, Purple

# Plotting
fig, ax = plt.subplots(figsize=(12, 6))

# Plot bars for each preprocessing technique
for i, preprocessing_technique in enumerate(preprocessing):
    bars = ax.bar(x + (i - 1.5) * width, accuracy_data[:, i], width, label=preprocessing_technique, color=colors[i])

    # Display accuracy values on top of each bar with smaller font size
    for bar in bars:
        yval = bar.get_height()
        ax.text(bar.get_x() + bar.get_width() / 2, yval + 0.01, f'{yval:.2f}%', ha='center', va='bottom', fontsize=6, rotation = 90)

# Adding labels and title
ax.set_xlabel('Models')
ax.set_ylabel('Accuracy (%)')
ax.set_title('Accuracy of Models with Different Preprocessing Techniques')
ax.set_xticks(x)
ax.set_xticklabels(models)
# ax.legend(title="Preprocessing Techniques")
ax.set_ylim(0, 110)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define models and preprocessing techniques
models = ['ViT', 'DeiT', 'Swin', 'UNet', 'CNN', 'Inception']
preprocessing = ['Normal', 'SRGAN', 'CLAHE', 'SRCNN']

# Sensitivity values for each model and preprocessing technique
sensitivity_data = np.array([
    [96.09, 95.35, 96.88, 94.16],  # ViT
    [96.88, 96.90, 97.66, 94.89],  # DeiT
    [33.33, 33.33, 33.33, 33.33],  # Swin
    [53.91, 50.39, 50.78, 56.25],  # UNet
    [78.91, 93.80, 70.31, 86.86],  # CNN
    [96.09, 95.35, 93.75, 90.62]   # Inception
])

# Create an array for x-axis positions (one for each model)
x = np.arange(len(models))

# Bar width
width = 0.15

# Set a color palette
colors = ['#6C9E5D', '#F4A300', '#1F77B4', '#9467BD']  # Muted Green, Amber, Blue, Purple

# Plotting
fig, ax = plt.subplots(figsize=(12, 6))

# Plot bars for each preprocessing technique
for i, preprocessing_technique in enumerate(preprocessing):
    bars = ax.bar(x + (i - 1.5) * width, sensitivity_data[:, i], width, label=preprocessing_technique, color=colors[i])

    # Display sensitivity values on top of each bar
    for bar in bars:
        yval = bar.get_height()
        ax.text(bar.get_x() + bar.get_width() / 2, yval + 0.01, f'{yval:.2f}%', ha='center', va='bottom', fontsize=6, rotation = 90)

# Adding labels and title
ax.set_xlabel('Models')
ax.set_ylabel('Sensitivity (%)')
ax.set_title('Sensitivity of Models with Different Preprocessing Techniques')
ax.set_xticks(x)
ax.set_xticklabels(models)
# ax.legend(title="Preprocessing Techniques")
ax.set_ylim(0, 110)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define models and preprocessing techniques
models = ['ViT', 'DeiT', 'Swin', 'UNet', 'CNN', 'Inception']
preprocessing = ['Normal', 'SRGAN', 'CLAHE', 'SRCNN']

# Specificity values for each model and preprocessing technique
specificity_data = np.array([
    [98.05, 97.67, 98.44, 97.08],  # ViT
    [98.44, 98.45, 98.83, 97.45],  # DeiT
    [np.nan, np.nan, np.nan, np.nan],  # Swin
    [54.40, 50.61, 50.90, 56.64],  # UNet
    [78.91, 93.80, 70.31, 86.86],  # CNN
    [98.05, 97.67, 96.88, 95.31]   # Inception
])

# Create an array for x-axis positions (one for each model)
x = np.arange(len(models))

# Bar width
width = 0.15

# Set a color palette
colors = ['#6C9E5D', '#F4A300', '#1F77B4', '#9467BD']  # Muted Green, Amber, Blue, Purple

# Plotting
fig, ax = plt.subplots(figsize=(12, 6))

# Plot bars for each preprocessing technique
for i, preprocessing_technique in enumerate(preprocessing):
    bars = ax.bar(x + (i - 1.5) * width, specificity_data[:, i], width, label=preprocessing_technique, color=colors[i])

    # Display specificity values on top of each bar
    for bar in bars:
        yval = bar.get_height()
        ax.text(bar.get_x() + bar.get_width() / 2, yval + 0.01, f'{yval:.2f}%', ha='center', va='bottom', fontsize=6, rotation = 90)

# Adding labels and title
ax.set_xlabel('Models')
ax.set_ylabel('Specificity (%)')
ax.set_title('Specificity of Models with Different Preprocessing Techniques')
ax.set_xticks(x)
ax.set_xticklabels(models)
# ax.legend(title="Preprocessing Techniques")
ax.set_ylim(0, 110)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define models and preprocessing techniques
models = ['ViT', 'DeiT', 'Swin', 'UNet', 'CNN', 'Inception']
preprocessing = ['Normal', 'SRGAN', 'CLAHE', 'SRCNN']

# Precision values for each model and preprocessing technique
precision_data = np.array([
    [96.11, 95.40, 96.91, 94.39],  # ViT
    [97.03, 96.93, 97.75, 94.89],  # DeiT
    [10.77, 10.60, 10.77, 12.28],  # Swin
    [52.80, 39.96, 45.26, 55.33],  # UNet
    [78.69, 93.75, 65.91, 87.00],  # CNN
    [96.09, 95.37, 93.72, 90.54]   # Inception
])

# Create an array for x-axis positions (one for each model)
x = np.arange(len(models))

# Bar width
width = 0.15

# Set a color palette
colors = ['#6C9E5D', '#F4A300', '#1F77B4', '#9467BD']  # Muted Green, Amber, Blue, Purple

# Plotting
fig, ax = plt.subplots(figsize=(12, 6))

# Plot bars for each preprocessing technique
for i, preprocessing_technique in enumerate(preprocessing):
    bars = ax.bar(x + (i - 1.5) * width, precision_data[:, i], width, label=preprocessing_technique, color=colors[i])

    # Display precision values on top of each bar
    for bar in bars:
        yval = bar.get_height()
        ax.text(bar.get_x() + bar.get_width() / 2, yval + 0.01, f'{yval:.2f}%', ha='center', va='bottom', fontsize=6, rotation = 90)

# Adding labels and title
ax.set_xlabel('Models')
ax.set_ylabel('Precision (%)')
ax.set_title('Precision of Models with Different Preprocessing Techniques')
ax.set_xticks(x)
ax.set_xticklabels(models)
# ax.legend(title="Preprocessing Techniques")
ax.set_ylim(0, 110)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define models and preprocessing techniques
models = ['ViT', 'DeiT', 'Swin', 'UNet', 'CNN', 'Inception']
preprocessing = ['Normal', 'SRGAN', 'CLAHE', 'SRCNN']

# MCC values for each model and preprocessing technique
mcc_data = np.array([
    [0.9415, 0.9305, 0.9532, 0.9138],  # ViT
    [0.9539, 0.9538, 0.9655, 0.9238],  # DeiT
    [0, 0, 0, 0],  # Swin
    [0.3223, 0.3027, 0.303, 0.3467],  # UNet
    [0.7224, 0.9091, 0.6202, 0.81],   # CNN
    [0.9428, 0.9308, 0.9091, 0.8676]   # Inception
])

# Create an array for x-axis positions (one for each model)
x = np.arange(len(models))

# Bar width
width = 0.15

# Set a color palette
colors = ['#6C9E5D', '#F4A300', '#1F77B4', '#9467BD']  # Muted Green, Amber, Blue, Purple

# Plotting
fig, ax = plt.subplots(figsize=(12, 6))

# Plot bars for each preprocessing technique
for i, preprocessing_technique in enumerate(preprocessing):
    bars = ax.bar(x + (i - 1.5) * width, mcc_data[:, i], width, label=preprocessing_technique, color=colors[i])

    # Display MCC values on top of each bar
    for bar in bars:
        yval = bar.get_height()
        ax.text(bar.get_x() + bar.get_width() / 2, yval + 0.01, f'{yval:.4f}', ha='center', va='bottom', fontsize=6, rotation = 90)

# Adding labels and title
ax.set_xlabel('Models')
ax.set_ylabel('Matthew Correlation Coefficient (MCC)')
ax.set_title('MCC of Models with Different Preprocessing Techniques')
ax.set_xticks(x)
ax.set_xticklabels(models)
#ax.legend(title="Preprocessing Techniques")
ax.set_ylim(0, 1.10)
# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define models and preprocessing techniques
models = ['ViT', 'DeiT', 'Swin', 'UNet', 'CNN', 'Inception']
preprocessing = ['Normal', 'SRGAN', 'CLAHE', 'SRCNN']

# Kappa values for each model and preprocessing technique
kappa_data = np.array([
    [0.9414, 0.9302, 0.9531, 0.9123],  # ViT
    [0.9531, 0.9535, 0.9649, 0.9232],  # DeiT
    [0, 0, 0, 0],  # Swin
    [0.3102, 0.2574, 0.263, 0.3447],  # UNet
    [0.6819, 0.9069, 0.5573, 0.8029],  # CNN
    [0.9414, 0.9302, 0.9061, 0.8596]   # Inception
])

# Create an array for x-axis positions (one for each model)
x = np.arange(len(models))

# Bar width
width = 0.15

# Set a color palette
colors = ['#6C9E5D', '#F4A300', '#1F77B4', '#9467BD']  # Muted Green, Amber, Blue, Purple

# Plotting
fig, ax = plt.subplots(figsize=(12, 6))

# Plot bars for each preprocessing technique
for i, preprocessing_technique in enumerate(preprocessing):
    bars = ax.bar(x + (i - 1.5) * width, kappa_data[:, i], width, label=preprocessing_technique, color=colors[i])

    # Display Kappa values on top of each bar
    for bar in bars:
        yval = bar.get_height()
        ax.text(bar.get_x() + bar.get_width() / 2, yval + 0.01, f'{yval:.4f}', ha='center', va='bottom', fontsize=6, rotation = 90)

# Adding labels and title
ax.set_xlabel('Models')
ax.set_ylabel('Kappa')
ax.set_title('Kappa of Models with Different Preprocessing Techniques')
ax.set_xticks(x)
ax.set_xticklabels(models)
# ax.legend(title="Preprocessing Techniques")
ax.set_ylim(0, 1.10)


# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define models and preprocessing techniques
models = ['ViT', 'DeiT', 'Swin', 'UNet', 'CNN', 'Inception']
preprocessing = ['Normal', 'SRGAN', 'CLAHE', 'SRCNN']

# F1 Score values for each model and preprocessing technique
f1_score_data = np.array([
    [96.09, 95.35, 96.88, 94.11],  # ViT
    [96.87, 96.88, 97.64, 94.84],  # DeiT
    [16.21, 15.99, 16.21, 18.18],  # Swin
    [54.95, 33.66, 52.01, 54.95],  # UNet
    [86.93, 94.20, 81.80, 88.51],  # CNN
    [96.37, 95.52, 94.31, 92.13]   # Inception
])

# Create an array for x-axis positions (one for each model)
x = np.arange(len(models))

# Bar width
width = 0.15

# Set a color palette
colors = ['#6C9E5D', '#F4A300', '#1F77B4', '#9467BD']  # Muted Green, Amber, Blue, Purple

# Plotting
fig, ax = plt.subplots(figsize=(12, 6))

# Plot bars for each preprocessing technique
for i, preprocessing_technique in enumerate(preprocessing):
    bars = ax.bar(x + (i - 1.5) * width, f1_score_data[:, i], width, label=preprocessing_technique, color=colors[i])

    # Display F1 score values on top of each bar
    for bar in bars:
        yval = bar.get_height()
        ax.text(bar.get_x() + bar.get_width() / 2, yval + 0.01, f'{yval:.2f}', ha='center', va='bottom', fontsize=6, rotation = 90)

# Adding labels and title
ax.set_xlabel('Models')
ax.set_ylabel('F1 Score')
ax.set_title('F1 Score of Models with Different Preprocessing Techniques')
ax.set_xticks(x)
ax.set_xticklabels(models)
ax.legend(title="Preprocessing Techniques")
ax.set_ylim(0, 110)


# Show the plot
plt.tight_layout()
plt.show()
